# %% [markdown]
# <a href="https://colab.research.google.com/github/namjuuuuu/BaekJoon/blob/main/Python_3%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3강

# %%
n = 5
type(n)
# Out:
# int

# %%
n = 5.1
type(n)
# Out:
# float

# %%
n1 = 5
n2 = 5.1
n3 = n1 + n2
type(n3)
# Out:
# float

# %%
n = "안녕하세요."
type(n)
# Out:
# str

# %%
n = True
type(n)
# Out:
# bool

# %%
n1 = "안녕하세요."
n2 = '안녕하세요.'
n3 = "A"
n4 = 'A'
n5 = " "
n6 = ' '
print(n1, n2, n3, n4, n5, n6)
# Out:
# 안녕하세요. 안녕하세요. A A

# %%
n1 = """안녕하세요
반갑습니다."""
n2 = '''안녕하세요
반갑습니다.'''
print(n1)
print(n2)
# Out:
# 안녕하세요
# 반갑습니다.
# 안녕하세요
# 반갑습니다.

# %%
print("안녕하세요.\n반갑습니다.")
# Out:
# 안녕하세요.
# 반갑습니다.

# %%
print("안녕하세요.\t반갑습니다.")
# Out:
# 안녕하세요.	반갑습니다.

# %%
print("안녕하세요.\b반갑습니다.")
# Out:
# 반갑습니다.

# %%
print("안녕하세요.\'반갑습니다.")
# Out:
# 안녕하세요.'반갑습니다.

# %%
print("안녕하세요.\\반갑습니다.")
# Out:
# 안녕하세요.\반갑습니다.

# %%
var = "안녕하세요." + "반갑습니다."
print(var)
# Out:
# 안녕하세요.반갑습니다.

# %%
var = "안녕하세요."
var += "반갑습니다."
print(var)
# Out:
# 안녕하세요.반갑습니다.

# %%
var = "안녕하세요."
var += 3
print(var)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4179133313.py in <cell line: 0>()
#       1 var = "안녕하세요."
# ----> 2 var += 3
#       3 print(var)
#
# TypeError: can only concatenate str (not "int") to str

# %%
var = "안녕하세요."
var *= 3
print(var)
# Out:
# 안녕하세요.안녕하세요.안녕하세요.

# %%
a = input("단어--> ")
b = input("단어--> ")
c = (a*2) + (b*2)
print(c)
# Out:
# 단어--> 사탕
# 단어--> 초콜릿
# 사탕사탕초콜릿초콜릿

# %%
print("\n")
print("줄바꿈\n연습")
print("\t탭키\t연습")
print("글자가 \"강조\"되는 효과1")
print("글자가 \'강조\'되는 효과2")
print("\\\\\\ 역슬래쉬 세 개 출력")
print("\n"+"\t"+"\\"+"를 그대로 출력")
# Out:
# 줄바꿈
# 연습
# 	탭키	연습
# 글자가 "강조"되는 효과1
# 글자가 '강조'되는 효과2
# \\\ 역슬래쉬 세 개 출력
#
# 	\를 그대로 출력

# %%
print("\n")
print("줄바꿈\n연습")
print("\t탭키\t연습")
print("글자가 \"강조\"되는 효과1")
print("글자가 \'강조\'되는 효과2")
print("\\\\\\ 역슬래쉬 세 개 출력")
print("\\n","\\t","\\"+"를 그대로 출력")
# Out:
# 줄바꿈
# 연습
# 	탭키	연습
# 글자가 "강조"되는 효과1
# 글자가 '강조'되는 효과2
# \\\ 역슬래쉬 세 개 출력
# \n \t \를 그대로 출력

# %%
var = "안녕하세요."
len(var)
# Out:
# 6

# %%
var = "안녕하세요. 반갑습니다!"
len(var)
# Out:
# 13

# %%
var1 = "안녕하세요!"
var2 = "  반갑습니다."
n = len(var1) + len(var2)
print("두 문자열의 길이 합은", n, "입니다.")
# Out:
# 두 문자열의 길이 합은 14 입니다.
